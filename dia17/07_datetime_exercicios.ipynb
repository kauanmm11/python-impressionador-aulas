# %% [markdown]
# ## Oferecendo desconto para cliente com base na última compra
#
# Suponha que você está trabalhando para uma empresa que deseja rastrear a atividade do cliente. Uma métrica que eles estão interessados é o tempo que passou desde a última transação do cliente. Se for muito tempo, eles podem oferecer um desconto para o cliente. Crie um script Python que mostra quanto tempo se passou desde a última compra do cliente. Se faz mais de 30 dias, mostre uma mensagem oferecendo um desconto para o cliente.

# %%
from datetime import datetime

data_inicial = datetime(2026,1,15)
data_final = datetime.now()
diferenca = data_final - data_inicial

if diferenca.days > 30:
    print('Parabéns, você ganhou um desconto!')
# Out:
# Parabéns, você ganhou um desconto!

# %% [markdown]
# ## Data e hora em diferentes fusos horários
#
# Uma empresa tem escritórios em São Paulo, Nova York e Tóquio. Crie um script Python que mostra a data e hora atuais nesses três fusos horários. Exiba, também, se estes escritórios estão abertos ou fechados (9h às 17h).

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

data_atual = datetime.now()

fuso_horario_sp = ZoneInfo('America/Sao_Paulo')
fuso_data_atual_sp = data_atual.astimezone(fuso_horario_sp)

fuso_horario_ny = ZoneInfo('America/New_York')
fuso_data_atual_ny = data_atual.astimezone(fuso_horario_ny)

fuso_horario_tk = ZoneInfo('Asia/Tokyo')
fuso_data_atual_tk = data_atual.astimezone(fuso_horario_tk)

print(f"Data/hora atual em São Paulo: {fuso_data_atual_sp}")
print(f"Data/hora atual em Nova York: {fuso_data_atual_ny}")
print(f"Data/hora atual em Tóquio: {fuso_data_atual_tk}")
# Out:
# Data/hora atual em São Paulo: 2026-03-12 19:17:10.113360-03:00
# Data/hora atual em Nova York: 2026-03-12 18:17:10.113360-04:00
# Data/hora atual em Tóquio: 2026-03-13 07:17:10.113360+09:00

# %%
def verificar_fuso(data_hora):
    if 9 >= data_hora.hour < 17:
        return 'aberto'
    else:
        return 'fechado'
        
print(f'O escritorio esta {verificar_fuso(data_atual)} as {fuso_data_atual_sp.hour}h, fica aberto entre 9h e 17h')
print(f'O escritorio esta {verificar_fuso(data_atual)} as {fuso_data_atual_ny.hour}h, fica aberto entre 9h e 17h')
print(f'O escritorio esta {verificar_fuso(data_atual)} as {fuso_data_atual_tk.hour}h, fica aberto entre 9h e 17h')
# Out:
# O escritorio esta fechado as 19h, fica aberto entre 9h e 17h
# O escritorio esta fechado as 18h, fica aberto entre 9h e 17h
# O escritorio esta fechado as 7h, fica aberto entre 9h e 17h
